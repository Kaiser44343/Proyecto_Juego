# %% [markdown]
# ### Notas para desarrolladores
# ---
# ! Decidir un nombre para el minijuego !
# **HTML**
# 1. Diseño:
# - Menu principal: Titulos del juego, Nueva partida, continuar, opciones (aunque esté vacio), y salir (cierra la web?)
# - Crear sobre el fondo un div padre, que contenga 4 divs hijos, en la parte inferior,esos divs hijos tienen  escondidos otros divs.
# - En la parte superior una barra de estado, nombre del personaje, tipo de clase.
# 2. Notas para Antonio :
# - El div padre #seleccion_personaje y todos sus divs hijos, están en oculto. La idea es q solo aparezca cuando se haga click al darle a nueva partida. Entonces hay que añadir un addEventListener para q se muestre al hacer click en el boton 'NewG'. teiene q usar style.display='flex' , para q ya no esté oculto y q ademas esté centrado.
#
# - En la logica del eventListener del boton continuar ('continue'), ademas de la logica del localstorage q uses, para q aparezca los divs esos con los q interactuar añadir lo mismo de antes style.display = 'flex';
# ---
# **CSS**
# - Estilos
# ---
# **JS**
# - Hacer un esquema del sistema de combate
# - Hacer un sistema para sala de cofre sin que pueda abusarse de la mecanica (adelantarse a bugs de estadisticas infinitas),posiblemente con un array con varios objetos,con un aprobabilidad cada vez mayor de que el cofre este vacio,haciendo que la sala no sea accesible mas
# - Preparar posibilidad de uno o varios finales
# - Preparar clases de enemigos,probablemente aleatorios o uno unico,con posibles debilidades(?)
